# %% [markdown]
# ### Data Collection
#
#
# 1. GET S&P 500 company info<br>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi import NewsApiClient
from pathlib import Path
# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\jakek\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ### 1. Get S&P 500 Data

# %%
# Get table of the S&P 500 tickers, CIK, and industry from Wikipedia
wiki_url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
cik_df = pd.read_html(wiki_url,header=0,index_col=0)[0]
cik_df['GICS Sector'] = cik_df['GICS Sector'].astype("category")
cik_df['GICS Sub Industry'] = cik_df['GICS Sector'].astype("category")
cik_df.tail(100)
# Out:
#                    Security SEC filings             GICS Sector  \
# Symbol
# RHI             Robert Half     reports             Industrials
# ROK     Rockwell Automation     reports             Industrials
# ROL                 Rollins     reports             Industrials
# ROP                   Roper     reports             Industrials
# ROST                   Ross     reports  Consumer Discretionary
# ...                     ...         ...                     ...
# YUM             Yum! Brands     reports  Consumer Discretionary
# ZBRA                  Zebra     reports  Information Technology
# ZBH           Zimmer Biomet     reports             Health Care
# ZION          Zions Bancorp     reports              Financials
# ZTS                  Zoetis     reports             Health Care
#
#                            GICS Sub-Industry   Headquarters Location  \
# Symbol
# RHI     Human Resource & Employment Services  Menlo Park, California
# ROK        Electrical Components & Equipment    Milwaukee, Wisconsin
# ROL      Environmental & Facilities Services        Atlanta, Georgia
# ROP                 Industrial Conglomerates       Sarasota, Florida
# ROST                          Apparel Retail      Dublin, California
# ...                                      ...                     ...
# YUM                              Restaurants    Louisville, Kentucky
# ZBRA      Electronic Equipment & Instruments  Lincolnshire, Illinois
# ZBH                    Health Care Equipment         Warsaw, Indiana
# ZION                          Regional Banks    Salt Lake City, Utah
# ZTS                          Pharmaceuticals  Parsippany, New Jersey
#
#        Date first added      CIK Founded       GICS Sub Industry
# Symbol
# RHI          2000-12-05   315213    1948             Industrials
# ROK                 NaN  1024478    1903             Industrials
# ROL          2018-10-01    84839    1948             Industrials
# ROP          2009-12-23   882835    1981             Industrials
# ROST         2009-12-21   745732    1982  Consumer Discretionary
# ...                 ...      ...     ...                     ...
# YUM          1997-10-06  1041061    1997  Consumer Discretionary
# ZBRA         2019-12-23   877212    1969  Information Technology
# ZBH          2001-08-07  1136869    1927             Health Care
# ZION         2001-06-22   109380    1873              Financials
# ZTS          2013-06-21  1555280    1952             Health Care
#
# [100 rows x 9 columns]

# %%
from newsapi import NewsApiClient
load_dotenv()
newsapi = NewsApiClient(api_key=os.environ["NEWS_API_KEY"])

# %%
headlines = newsapi.get_everything(
    q="S&P 1000" "",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# %%
# Create the S&p 500 sentiment scores DataFrame
sentiments = []

for article in headlines["articles"]:
    try:
        
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        sentiments.append({
            
            
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
            "Text": text
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
df = pd.DataFrame(sentiments)

# Reorder DataFrame columns
cols = ["Compound", "Positive", "Negative", "Neutral","Text"]
df = df[cols]

df.head(10)
# Out:
#    Compound  Positive  Negative  Neutral  \
# 0   -0.6369     0.000     0.144    0.856
# 1    0.5574     0.162     0.044    0.795
# 2   -0.0516     0.070     0.101    0.829
# 3   -0.4215     0.050     0.132    0.819
# 4   -0.3182     0.000     0.067    0.933
# 5    0.5423     0.111     0.000    0.889
# 6   -0.0516     0.043     0.048    0.909
# 7   -0.1779     0.000     0.048    0.952
# 8   -0.2960     0.000     0.056    0.944
# 9    0.9118     0.318     0.000    0.682
#
#                                                 Text
# 0  With volatility being the catchword now in the...
# 1  Designed to provide broad exposure to the Larg...
# 2  If you're interested in broad exposure to the ...
# 3  Feb 22 (Reuters) - Futures for Canada's main s...
# 4  Feb 25 (Reuters) - Futures for Canada's main s...
# 5  Feb 18 (Reuters) - Futures for Canada's main s...
# 6  Launched on 12/23/2014, the Invesco Russell 10...
# 7  Looking for broad exposure to the Mid Cap Blen...
# 8  Feb 16 (Reuters) - Futures for Canada's main s...
# 9  Wall Street has been witnessing some strength ...

# %%
df.describe()
# Out:
#          Compound    Positive    Negative     Neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.346973    0.103950    0.019860    0.876230
# std      0.376791    0.078357    0.043097    0.081189
# min     -0.757900    0.000000    0.000000    0.682000
# 25%      0.000000    0.048250    0.000000    0.832000
# 50%      0.381800    0.111000    0.000000    0.856000
# 75%      0.636900    0.148000    0.000000    0.926250
# max      0.911800    0.318000    0.249000    1.000000

# %%
# Instantiate the lemmatizer
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Expand the default stopwords list if necessary
sw = set(stopwords.words('english'))

# %%
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    
    regex = re.compile("[^a-zA-Z ]")
   
    # Create a tokenized list of the words
    re_clean = regex.sub('', text)
    words = word_tokenize(re_clean)
    words = word_tokenize(re_clean)
    words = word_tokenize(re_clean.lower())
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase
    words = [word for word in words if word not in sw]
    
    # Remove the stop words
   
    return lem

tokenizer(df.iloc[0]['Text'])
# Out:
# ['with',
#  'volatility',
#  'being',
#  'the',
#  'catchword',
#  'now',
#  'in',
#  'the',
#  'broader',
#  'equity',
#  'market',
#  'due',
#  'to',
#  'a',
#  'hawkish',
#  'fed',
#  'and',
#  'geopolitical',
#  'tension',
#  'related',
#  'to',
#  'russia',
#  'and',
#  'ukraine',
#  'investor',
#  'might',
#  'be',
#  'clueless',
#  'about',
#  'the',
#  'future',
#  'movemen',
#  'char']

# %%
df['tokens'] = df['Text'].apply(tokenizer)
df
# Out:
#     Compound  Positive  Negative  Neutral  \
# 0    -0.6369     0.000     0.144    0.856
# 1     0.5574     0.162     0.044    0.795
# 2    -0.0516     0.070     0.101    0.829
# 3    -0.4215     0.050     0.132    0.819
# 4    -0.3182     0.000     0.067    0.933
# ..       ...       ...       ...      ...
# 95    0.4588     0.070     0.000    0.930
# 96    0.3400     0.070     0.000    0.930
# 97    0.3818     0.075     0.000    0.925
# 98    0.7430     0.213     0.000    0.787
# 99    0.0000     0.000     0.000    1.000
#
#                                                  Text  \
# 0   With volatility being the catchword now in the...
# 1   Designed to provide broad exposure to the Larg...
# 2   If you're interested in broad exposure to the ...
# 3   Feb 22 (Reuters) - Futures for Canada's main s...
# 4   Feb 25 (Reuters) - Futures for Canada's main s...
# ..                                                ...
# 95  Welcome everyone to the131st edition of ‘Hot G...
# 96  Smead Capital Management, an investment manage...
# 97  Vitalii Stamat/iStock via Getty Images\r\nRamb...
# 98  DULUTH, Ga.--(BUSINESS WIRE)--Primerica, Inc. ...
# 99  AUSTIN, Texas--(BUSINESS WIRE)--EZCORP, Inc. (...
#
#                                                tokens
# 0   [with, volatility, being, the, catchword, now,...
# 1   [designed, to, provide, broad, exposure, to, t...
# 2   [if, youre, interested, in, broad, exposure, t...
# 3   [feb, reuters, future, for, canada, main, stoc...
# 4   [feb, reuters, future, for, canada, main, stoc...
# ..                                                ...
# 95  [welcome, everyone, to, thest, edition, of, ho...
# 96  [smead, capital, management, an, investment, m...
# 97  [vitalii, stamatistock, via, getty, imagesramb...
# 98  [duluth, gabusiness, wireprimerica, inc, nysep...
# 99  [austin, texasbusiness, wireezcorp, inc, nasda...
#
# [100 rows x 6 columns]

# %%
from collections import Counter
from nltk import ngrams

# %%
def get_token(df):
    tokens = []
    for i in df['tokens']:
        tokens.extend(i)
    return tokens

tokens = get_token(df)

# %%
def bigram_counter(tokens, N):
    words_count = dict(Counter(ngrams(tokens, n=2)))
    return words_count

# %%
# Function token_count generates the top 10 words for a given stock
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
token_count(tokens, 10)
# Out:
# [('the', 145),
#  ('of', 107),
#  ('char', 100),
#  ('to', 83),
#  ('a', 69),
#  ('you', 52),
#  ('for', 46),
#  ('can', 44),
#  ('with', 41),
#  ('fund', 38)]

# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
text = ' '.join(df['Text'])
text
# Out:
# "With volatility being the catchword now in the broader equity market due to a hawkish Fed and geopolitical tensions related to Russia and Ukraine, investors might be clueless about the future movemen… [+4981 chars] Designed to provide broad exposure to the Large Cap Value segment of the US equity market, the SPDR Portfolio S&amp;P 500 Value ETF (SPYV) is a passively managed exchange traded fund launched on 09/2… [+4403 chars] If you're interested in broad exposure to the Large Cap Blend segment of the US equity market, look no further than the Schwab 1000 Index ETF (SCHK), a passively managed exchange traded fund launched… [+4295 chars] Feb 22 (Reuters) - Futures for Canada's main stock index fell on Tuesday, with investors joining a global flight from risky assets, as tensions between Russia and Ukraine escalated, although stronger… [+2456 chars] Feb 25 (Reuters) - Futures for Canada's main stock index fell on Friday as commodity prices weakened, while Russia's invasion of Ukraine kept investors on edge.\r\nMarch futures on the S&amp;P/TSX inde… [+3047 chars] Feb 18 (Reuters) - Futures for Canada's main stock index rose on Friday, mirroring upbeat global sentiment on optimism over a potential diplomatic resolution to the Russia-Ukraine standoff, although … [+1984 chars] Launched on 12/23/2014, the Invesco Russell 1000 Equal Weight ETF (EQAL) is a passively managed exchange traded fund designed to provide a broad exposure to the Large Cap Blend segment of the US equi… [+4162 chars] Looking for broad exposure to the Mid Cap Blend segment of the US equity market? You should consider the SPDR Portfolio S&amp;P 400 Mid Cap ETF (SPMD), a passively managed exchange traded fund launch… [+4231 chars] Feb 16 (Reuters) - Futures for Canada's main stock index inched lower on Wednesday, ahead of slew of economic data due later in the day that could offer cues on the central bank's rate hike plans, al… [+2697 chars] Wall Street has been witnessing some strength on the bourses as investors are cheering impressive fourth-quarter earnings reports. The S&amp;P 500 and Nasdaq Composite indices have been gaining solid… [+4911 chars] Feb 22 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nU.S. STOCKS GYRATE, BUT… [+2582 chars] Feb 25 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nSTOCKS GAIN BROADLY, BU… [+3411 chars] Feb 28 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nU.S. STOCKS SLIDE AS SA… [+4264 chars] Feb 15 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nWALL STREET ENDS SHARPL… [+13510 chars] Feb 28 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nEXCHANGE-TRADED FUNDS: … [+8322 chars] Feb 28 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nCHICAGO PMI WEAKENS. NO… [+10144 chars] Feb 25 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nNOT SO SWIFT YET - WHY … [+5084 chars] Feb 25 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nWHAT'S IN $300 BILLION?… [+6043 chars] Feb 25 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can s ...

# %%
doc = nlp(text)

# %%
# Add a title to the document
doc.user_data["title"] = "NER"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">With volatility being the catchword now in the broader equity market due to a hawkish
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and geopolitical tensions related to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , investors might be clueless about the future movemen… [+4981 chars] Designed to provide broad exposure to the Large Cap Value segment of the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  equity market, the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SPDR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Portfolio S&amp;amp;P
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Value ETF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  (SPYV) is a passively managed exchange traded fund launched on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     09/2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# … [+4403 chars] If you're interested in broad exposure to the Large Cap Blend segment of the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  equity market, look no further than the Schwab
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Index
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ETF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SCHK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), a passively managed exchange traded fund launched… [+4295 chars]
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Feb 22
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Futures for
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Canada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's main stock index fell on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , with investors joining a global flight from risky assets, as tensions between
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  escalated, although stronger… [+2456 chars]
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Feb 25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Futures for
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Canada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's main stock index fell on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  as commodity prices weakened, while
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's invasion of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-he

# %%
# List all Entities
org_list = []

for ent in doc.ents:
    if ent.label_ == 'ORG':
        org_list.append(ent.text)

org_list = Counter(org_list).most_common(100)

df_org = pd.DataFrame(org_list, columns = ['text', 'count'])

df_org.head(50)
# Out:
#                                text  count
# 0                           Reuters     26
# 1                      Getty Images      9
# 2                     Polen Capital      9
# 3                Polen Focus Growth      9
# 4                             Polen      9
# 5       RiverPark Large Growth Fund      9
# 6   The RiverPark Large Growth Fund      9
# 7                              SPDR      2
# 8                               ETF      2
# 9                               AIX      2
# 10                           iStock      2
# 11                             NYSE      2
# 12                      SelectQuote      2
# 13            Washington University      2
# 14                  VMbreakouts.com      2
# 15                              MDA      2
# 16                            Intel      2
# 17                              Fed      1
# 18                             SCHK      1
# 19                              TSX      1
# 20                             SPMD      1
# 21                 Nasdaq Composite      1
# 22                          BROADLY      1
# 23                               SA      1
# 24                  EXCHANGE-TRADED      1
# 25                              PMI      1
# 26                          WEAKENS      1
# 27                    CREDIT SPREAD      1
# 28                              CAP      1
# 29                         TREASURY      1
# 30     the Zacks Consensus Estimate      1
# 31          CHIP STOCKS SURGE AFTER      1
# 32                            +9246      1
# 33                         ETF Wrap      1
# 34                          TUESDAY      1
# 35                              SUN      1
# 36                            ROUND      1
# 37             BofA Global Research      1
# 38          INDIVIDUAL INVESTORS AS      1
# 39                             IEEE      1
# 40                      Interceptor      1
# 41                              IPS      1
# 42                Immediate Release      1
# 43        the Zacks Equity Research      1
# 44       Global Market Intelligence      1
# 45  the Renaissance Virtual Machine      1
# 46                     IBM Research      1
# 47     Matteo Colombo/DigitalVision      1
# 48         Hoya Capital Real Estate      1
# 49                           the S&      1

# %%
# Dropping Reuters as it is a publisher
df_org = df_org.iloc[2:]
df_org
# Out:
#                                      text  count
# 2                           Polen Capital      9
# 3                      Polen Focus Growth      9
# 4                                   Polen      9
# 5             RiverPark Large Growth Fund      9
# 6         The RiverPark Large Growth Fund      9
# ..                                    ...    ...
# 79  Ga.--(BUSINESS WIRE)--Primerica, Inc.      1
# 80                                    PRI      1
# 81                 the Board of Directors      1
# 82                                   +996      1
# 83                                  +1178      1
#
# [82 rows x 2 columns]

# %%
headlines = newsapi.get_everything(
    q="Polen" "",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# %%
# Create the Polen sentiment scores DataFrame
sentiments = []

for article in headlines["articles"]:
    try:
        
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        sentiments.append({
            
            
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
            "Text": text
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
df_polen = pd.DataFrame(sentiments)

# Reorder DataFrame columns
cols = ["Compound", "Positive", "Negative", "Neutral","Text"]
df_polen = df[cols]

df_polen.head(10)
# Out:
#    Compound  Positive  Negative  Neutral  \
# 0   -0.6369     0.000     0.144    0.856
# 1    0.5574     0.162     0.044    0.795
# 2   -0.0516     0.070     0.101    0.829
# 3   -0.4215     0.050     0.132    0.819
# 4   -0.3182     0.000     0.067    0.933
# 5    0.5423     0.111     0.000    0.889
# 6   -0.0516     0.043     0.048    0.909
# 7   -0.1779     0.000     0.048    0.952
# 8   -0.2960     0.000     0.056    0.944
# 9    0.9118     0.318     0.000    0.682
#
#                                                 Text
# 0  With volatility being the catchword now in the...
# 1  Designed to provide broad exposure to the Larg...
# 2  If you're interested in broad exposure to the ...
# 3  Feb 22 (Reuters) - Futures for Canada's main s...
# 4  Feb 25 (Reuters) - Futures for Canada's main s...
# 5  Feb 18 (Reuters) - Futures for Canada's main s...
# 6  Launched on 12/23/2014, the Invesco Russell 10...
# 7  Looking for broad exposure to the Mid Cap Blen...
# 8  Feb 16 (Reuters) - Futures for Canada's main s...
# 9  Wall Street has been witnessing some strength ...

# %%
df_polen.describe()
# Out:
#          Compound    Positive    Negative     Neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.346973    0.103950    0.019860    0.876230
# std      0.376791    0.078357    0.043097    0.081189
# min     -0.757900    0.000000    0.000000    0.682000
# 25%      0.000000    0.048250    0.000000    0.832000
# 50%      0.381800    0.111000    0.000000    0.856000
# 75%      0.636900    0.148000    0.000000    0.926250
# max      0.911800    0.318000    0.249000    1.000000
