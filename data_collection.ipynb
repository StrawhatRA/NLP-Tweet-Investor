# %% [markdown]
# ### Data Collection
#
#
# 1. GET S&P 500 company info<br>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi import NewsApiClient
from pathlib import Path
# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\Straw
# [nltk_data]     Hat\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ### 1. Get S&P 500 Data

# %%
# Get table of the S&P 500 tickers, CIK, and industry from Wikipedia
wiki_url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
cik_df = pd.read_html(wiki_url,header=0,index_col=0)[0]
cik_df['GICS Sector'] = cik_df['GICS Sector'].astype("category")
cik_df['GICS Sub Industry'] = cik_df['GICS Sector'].astype("category")
cik_df.head(100)
# Out:
#                   Security SEC filings             GICS Sector  \
# Symbol
# MMM                     3M     reports             Industrials
# AOS            A. O. Smith     reports             Industrials
# ABT                 Abbott     reports             Health Care
# ABBV                AbbVie     reports             Health Care
# ABMD               Abiomed     reports             Health Care
# ...                    ...         ...                     ...
# CE                Celanese     reports               Materials
# CNC                Centene     reports             Health Care
# CNP     CenterPoint Energy     reports               Utilities
# CDAY              Ceridian     reports  Information Technology
# CERN                Cerner     reports             Health Care
#
#                GICS Sub-Industry        Headquarters Location  \
# Symbol
# MMM     Industrial Conglomerates        Saint Paul, Minnesota
# AOS            Building Products         Milwaukee, Wisconsin
# ABT        Health Care Equipment      North Chicago, Illinois
# ABBV             Pharmaceuticals      North Chicago, Illinois
# ABMD       Health Care Equipment       Danvers, Massachusetts
# ...                          ...                          ...
# CE           Specialty Chemicals                Irving, Texas
# CNC          Managed Health Care          St. Louis, Missouri
# CNP              Multi-Utilities               Houston, Texas
# CDAY        Application Software       Minneapolis, Minnesota
# CERN      Health Care Technology  North Kansas City, Missouri
#
#        Date first added      CIK      Founded       GICS Sub Industry
# Symbol
# MMM          1976-08-09    66740         1902             Industrials
# AOS          2017-07-26    91142         1916             Industrials
# ABT          1964-03-31     1800         1888             Health Care
# ABBV         2012-12-31  1551152  2013 (1888)             Health Care
# ABMD         2018-05-31   815094         1981             Health Care
# ...                 ...      ...          ...                     ...
# CE           2018-12-24  1306830         1918               Materials
# CNC          2016-03-30  1071739         1984             Health Care
# CNP          1985-07-31  1130310         1882               Utilities
# CDAY         2021-09-20  1725057         1992  Information Technology
# CERN         2010-04-30   804753         1979             Health Care
#
# [100 rows x 9 columns]

# %%
from newsapi import NewsApiClient
load_dotenv()
newsapi = NewsApiClient(api_key=os.environ["NEWS_API_KEY"])

# %%
headlines = newsapi.get_everything(
    q="S&P 500" "",
    language="en",
    page_size=100,
    sort_by="relevancy"
)

# %%
# Create the S&p 500 sentiment scores DataFrame
sentiments = []

for article in headlines["articles"]:
    try:
        
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        sentiments.append({
            
            
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
            "Text": text
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
df = pd.DataFrame(sentiments)

# Reorder DataFrame columns
cols = ["Compound", "Positive", "Negative", "Neutral","Text"]
df = df[cols]

df.head(10)
# Out:
#    Compound  Positive  Negative  Neutral  \
# 0    0.6369     0.148     0.000    0.852
# 1   -0.6249     0.000     0.124    0.876
# 2    0.1531     0.046     0.000    0.954
# 3    0.6369     0.148     0.000    0.852
# 4    0.6908     0.151     0.000    0.849
# 5    0.6369     0.144     0.000    0.856
# 6   -0.4404     0.000     0.086    0.914
# 7    0.6369     0.152     0.000    0.848
# 8   -0.5859     0.000     0.127    0.873
# 9    0.0000     0.000     0.000    1.000
#
#                                                 Text
# 0  Feb 11 - Welcome to the home for real-time cov...
# 1  Posted \r\nWall Street's main indexes fell on ...
# 2  There are plenty of solid reasons why investor...
# 3  Feb 9 - Welcome to the home for real-time cove...
# 4  Feb 10 (Reuters) - Futures tracking the S&amp;...
# 5  Feb 11 - Welcome to the home for real-time cov...
# 6  NEW YORK (Reuters) - The S&amp;P 500 index end...
# 7  Feb 7 - Welcome to the home for real-time cove...
# 8  Feb 14 (Reuters) - Goldman Sachs has tempered ...
# 9  NEW YORK, Feb 22 (Reuters) - The S&amp;P 500's...

# %%
df.describe()
# Out:
#          Compound    Positive    Negative     Neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.168539    0.101600    0.054140    0.844230
# std      0.532687    0.081072    0.069649    0.082521
# min     -0.836000    0.000000    0.000000    0.633000
# 25%     -0.307000    0.000000    0.000000    0.791250
# 50%      0.261600    0.118000    0.000000    0.849500
# 75%      0.636900    0.152000    0.111250    0.873750
# max      0.910000    0.287000    0.282000    1.000000

# %%
# Instantiate the lemmatizer
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Expand the default stopwords list if necessary
sw = set(stopwords.words('english'))

# %%
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    
    regex = re.compile("[^a-zA-Z ]")
   
    # Create a tokenized list of the words
    re_clean = regex.sub('', text)
    words = word_tokenize(re_clean)
    words = word_tokenize(re_clean)
    words = word_tokenize(re_clean.lower())
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase
    words = [word for word in words if word not in sw]
    
    # Remove the stop words
   
    return lem

tokenizer(df.iloc[0]['Text'])
# Out:
# ['feb',
#  'welcome',
#  'to',
#  'the',
#  'home',
#  'for',
#  'realtime',
#  'coverage',
#  'of',
#  'market',
#  'brought',
#  'to',
#  'you',
#  'by',
#  'reuters',
#  'reporter',
#  'you',
#  'can',
#  'share',
#  'your',
#  'thought',
#  'with',
#  'u',
#  'at',
#  'marketsresearchthomsonreuterscomsampp',
#  'looking',
#  'fo',
#  'char']

# %%
df['tokens'] = df['Text'].apply(tokenizer)
df
# Out:
#     Compound  Positive  Negative  Neutral  \
# 0     0.6369     0.148     0.000    0.852
# 1    -0.6249     0.000     0.124    0.876
# 2     0.1531     0.046     0.000    0.954
# 3     0.6369     0.148     0.000    0.852
# 4     0.6908     0.151     0.000    0.849
# ..       ...       ...       ...      ...
# 95    0.8531     0.243     0.000    0.757
# 96   -0.6249     0.000     0.150    0.850
# 97    0.6369     0.123     0.000    0.877
# 98    0.8038     0.215     0.000    0.785
# 99   -0.6249     0.000     0.128    0.872
#
#                                                  Text  \
# 0   Feb 11 - Welcome to the home for real-time cov...
# 1   Posted \r\nWall Street's main indexes fell on ...
# 2   There are plenty of solid reasons why investor...
# 3   Feb 9 - Welcome to the home for real-time cove...
# 4   Feb 10 (Reuters) - Futures tracking the S&amp;...
# ..                                                ...
# 95  Feb 25 - Welcome to the home for real-time cov...
# 96  NEW YORK (Reuters) - Geopolitical worries are ...
# 97  Fortune 500 fintech company Global Payments (G...
# 98  Feb 28 - Welcome to the home for real-time cov...
# 99  Feb 23 (Reuters) - U.S. stock index futures ro...
#
#                                                tokens
# 0   [feb, welcome, to, the, home, for, realtime, c...
# 1   [posted, wall, street, main, index, fell, on, ...
# 2   [there, are, plenty, of, solid, reason, why, i...
# 3   [feb, welcome, to, the, home, for, realtime, c...
# 4   [feb, reuters, future, tracking, the, sampp, a...
# ..                                                ...
# 95  [feb, welcome, to, the, home, for, realtime, c...
# 96  [new, york, reuters, geopolitical, worry, are,...
# 97  [fortune, fintech, company, global, payment, g...
# 98  [feb, welcome, to, the, home, for, realtime, c...
# 99  [feb, reuters, u, stock, index, future, rose, ...
#
# [100 rows x 6 columns]

# %%
from collections import Counter
from nltk import ngrams

# %%
def get_token(df):
    tokens = []
    for i in df['tokens']:
        tokens.extend(i)
    return tokens

tokens = get_token(df)

# %%
def bigram_counter(tokens, N):
    words_count = dict(Counter(ngrams(tokens, n=2)))
    return words_count

# %%
# Function token_count generates the top 10 words for a given stock
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
token_count(tokens, 10)
# Out:
# [('the', 160),
#  ('to', 116),
#  ('char', 100),
#  ('of', 76),
#  ('you', 70),
#  ('a', 69),
#  ('u', 61),
#  ('for', 57),
#  ('reuters', 56),
#  ('on', 53)]

# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
text = ' '.join(df['Text'])
text
# Out:
# 'Feb 11 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nS&amp;P 500: LOOKING FO… [+2166 chars] Posted \r\nWall Street\'s main indexes fell on Tuesday, with the S&amp;P 500 confirming a correction, as the Ukraine-Russia crisis kept investors on edge after Russian President Vladimir Putin recognize… [+107 chars] There are plenty of solid reasons why investors view the Standard &amp; Poors 500 Index (S&amp;P 500) as a benchmark for both the economy and their individual portfolios. This index contains some of … [+4559 chars] Feb 9 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nS&amp;P 500, NASDAQ UP 1… [+5128 chars] Feb 10 (Reuters) - Futures tracking the S&amp;P 500 and the Nasdaq slipped on Thursday after the indexes notched strong gains in the past two sessions, with investors awaiting U.S. inflation data tha… [+3087 chars] Feb 11 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nS&amp;P 500 EDGES UP EA… [+2612 chars] NEW YORK (Reuters) - The S&amp;P 500 index ended weaker on Monday, partly recovering from a steep late-afternoon sell-off, as U.S. plans to close its Kyiv embassy in Ukraine sent simmering geopolitic… [+2652 chars] Feb 7 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nS&amp;P 500, NASDAQ FALL… [+9386 chars] Feb 14 (Reuters) - Goldman Sachs has tempered its outlook for the S&amp;P 500 index (.SPX), expecting it to stay below the 5,000 mark this year as rising inflation threatens to derail a nascent recov… [+1388 chars] NEW YORK, Feb 22 (Reuters) - The S&amp;P 500\'s (.SPX) 1% slump on Tuesday confirmed that the world\'s most watched stock index was in a correction for the first time since the 2020 Wall Street plunge … [+2033 chars] Feb 23 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nS&amp;P 500: AS TRADERS… [+1971 chars] Feb 17 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nRBC STICKING WITH 5,050… [+11198 chars] March 1 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nPRESIDENT BIDEN\'S FIRS… [+12747 chars] Feb 8 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nS&amp;P 500 EASES EARLY,… [+2681 chars] Feb 28 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nS&amp;P 500 INDEX ATTEM… [+1931 chars] Feb 15 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nS&amp;P 500 FUTURES WEI… [+1123 chars] Feb 23 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nFOR THE S&amp;P 500, IT… [+9622 chars] Feb 7 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. You can share your thoughts with us at markets.research@thomsonreuters.com\r\nAMID JUNKY ACTION, S&amp… [+1905 chars] Feb 9 - Welcome to the home for real-time coverage of markets brought to you by Reuters reporters. ...

# %%
doc = nlp(text)

# %%
# Add a title to the document
doc.user_data["title"] = "NER"

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Feb 11 - Welcome to the home for real-time coverage of markets brought to you by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>S&amp;amp;P
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>Wall Street's main indexes fell on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , with the S&amp;amp;P
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  confirming a correction, as the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  crisis kept investors on edge after
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vladimir Putin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  recognize… [+107 chars] There are plenty of solid reasons why investors view the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Standard &amp;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# amp; Poors
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Index (S&amp;amp;P
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ) as a benchmark for both the economy and their individual portfolios. This index contains some of … [+4559 chars] Feb 9 - Welcome to the home for real-time coverage of markets brought to you by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>S&amp;amp;P
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NASDAQ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  UP
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# … [+5128 chars] Feb 10 (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Futures tracking the S&amp;amp;P
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  and the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nasdaq
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  slipped on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  after the indexes notched strong gains in the past
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  sessions, with investors awaiting
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  inflation data tha… [+3087 chars] Feb 11 - Welcome to the home for real-time coverage of markets brought to you by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>S&amp;amp;P
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padd

# %%
# List all Entities
for ent in doc.ents:
    print('{} {}'.format(ent.text, ent.label_))
# Out:
# Reuters ORG
# 500 CARDINAL
# Tuesday DATE
# 500 CARDINAL
# Ukraine GPE
# Russia GPE
# Russian NORP
# Vladimir Putin PERSON
# Standard & ORG
# 500 CARDINAL
# 500 CARDINAL
# Reuters ORG
# 500 CARDINAL
# NASDAQ ORG
# 1 CARDINAL
# Reuters ORG
# 500 CARDINAL
# Nasdaq ORG
# Thursday DATE
# two CARDINAL
# U.S. GPE
# Reuters ORG
# 500 CARDINAL
# EDGES ORG
# NEW YORK GPE
# Reuters ORG
# 500 CARDINAL
# Monday DATE
# late-afternoon TIME
# U.S. GPE
# Ukraine GPE
# Reuters ORG
# 500 CARDINAL
# NASDAQ FALL GPE
# Feb 14 DATE
# Reuters ORG
# Goldman Sachs ORG
# 500 CARDINAL
# 5,000 CARDINAL
# this year DATE
# NEW YORK GPE
# Feb 22 DATE
# Reuters ORG
# 500 CARDINAL
# 1% PERCENT
# Tuesday DATE
# first ORDINAL
# 2020 DATE
# Reuters ORG
# 500 CARDINAL
# Reuters ORG
# RBC ORG
# 5,050 CARDINAL
# March 1 - Welcome DATE
# Reuters ORG
# BIDEN'S ORG
# Reuters ORG
# 500 CARDINAL
# EASES ORG
# Reuters ORG
# 500 CARDINAL
# Reuters ORG
# 500 CARDINAL
# Reuters ORG
# 500 CARDINAL
# Reuters ORG
# Reuters ORG
# SUPER BOWL SHOWDOWN ORG
# WIL ORG
# Reuters ORG
# 70% PERCENT
# 500 CARDINAL
# Reuters ORG
# 500 CARDINAL
# Reuters ORG
# U.S. GPE
# UK GPE
# European NORP
# Biden ORG
# Russia GPE
# Russia GPE
# Invesco ORG
# 500 CARDINAL
# Equal Weight Industrials ORG
# America GPE
# Mexico GPE
# Federal Reserve ORG
# 0% PERCENT
# Mexico GPE
# 5.5% PERCENT
# one CARDINAL
# Fed ORG
# Russia GPE
# Ukraine GPE
# US GPE
# SPDR ORG
# 500 CARDINAL
# Value ETF PRODUCT
# 09/2 CARDINAL
# US GPE
# Invesco ORG
# 500 CARDINAL
# 06/17/2011 GPE
# Invesco ORG
# 500 CARDINAL
# Equal Weight Consumer Discretionary ETF WORK_OF_ART
# 11/01/2006 DATE
# Invesco ORG
# 500 CARDINAL
# Equal Weight Utilities ORG
# RYU ORG
# Utilities ORG
# 500 CARDINAL
# Monday DATE
# U.S. GPE
# Ukraine GPE
# ViacomCBS Inc ORG
# 21% PERCENT
# 28.45 MONEY
# 500 CARDINAL
# fourth-quarter DATE
# 500 CARDINAL
# two week DATE
# 0.8% PERCENT
# Russia GPE
# Ukraine GPE
# a week DATE
# Nasdaq ORG
# 500 CARDINAL
# Thursday DATE
# Ukraine GPE
# 12:23 CARDINAL
# ViacomCBS Inc ORG
# 21% PERCENT
# 28.45 MONEY
# 500 CARDINAL
# fourth-quarter DATE
# US GPE
# Monday DATE
# Russia GPE
# Ukraine GPE
# 500 CARDINAL
# third ORDINAL
# Yasin Ebrahim PERSON
# Investing.com ORG
# 500 CARDINAL
# Monday DATE
# Russia GPE
# Wednesday DATE
# Tuesday DATE
# 500 CARDINAL
# Dow ORG
# The Market Bottoms In Wake Of Ukraine Invasion ORG
# Ukraine GPE
# Russia GPE
# 500 CARDINAL
# NYS ORG
# 500 CARDINAL
# another 6% PERCENT
# Monday DATE
# Ukraine GPE
# Western NORP
# Russia GPE
# Goldman Sachs ORG
# Russian Pr PERSON
# Feb 10 DATE
# Reuters ORG
# Italy GPE
# April DATE
# Depositphotos.com - MarketBeat ORG
# Russia GPE
# 500 CARDINAL
# SPY ORG
# 2 CARDINAL
# Russia GPE
# Ukraine GPE
# 2 CARDINAL
# 500 CARDINAL
# 10% PERCENT
# Dow ORG
# its worst day of 2022 DATE
# 500 CARDINAL
# daily DATE
# two weeks DATE
# 500 CARDINAL
# Nasdaq ORG
# over 1% PERCENT
# Tuesday DATE
# Russia GPE
# Ukraine GPE
# 500 CARDINAL
# Wednesday DATE
# the U.S. Federal Reserve ORG
# January DATE
# Feb 22 DATE
# Reuters ORG
# 500 CARDINAL
# Russia GPE
# Ukraine GPE
# 500 CARDINAL
# 2-week DATE
# 1.8% PERCENT
# Russia GPE
# Ukraine GPE
# 2022 DATE
# last week DATE
# the week ending Feb 11 DATE
# the week DATE
# Reuters ORG
# INDIVIDUAL ORG
# Reuters ORG
# UMICH ORG
# Reuters ORG
# YEN ORG
# Feb 28 DATE
# Reuters ORG
# U.S. GPE
# more than 1% PERCENT
# Monday DATE
# Western NORP
# Russia GPE
# Reuters ORG
# NASDAQ ORG
# ON AMAZON BOOS ORG
# Reuters ORG
# MATERIALS OUT FRONT THI ORG
# U.S. GPE
# MegaCap ETF PERSON
# USMC ORG
# Reuters ORG
# COVID-19 HOTT PERSON
# Reuters ORG
# U.S. GPE
# Ukraine GPE
# Russia GPE
# Feb 17 DATE
# three CARDINAL
# the day DATE
# NEW YORK GPE
# Feb 21 DATE
# Reuters ORG
# U.S. GPE
# Monday DATE
# Russian NORP
# Vladimir Putin PERSON
# two CARDINAL
# Ukraine GPE
# NEW YORK GPE
# Feb 4 DATE
# Reuters ORG
# next weeks DATE
# U.S. GPE
# March 4 DATE
# Reuters ORG
# U.S. GPE
# Friday DATE
# February DATE
# Ukraine GPE
# Reuters ORG
# Wednesday DATE
# Federal Reserve Chair ORG
# Jerome Powell PERSON
# FILE ORG
# Reuters ORG
# U.S. GPE
# Reuters ORG
# Reuters ORG
# UNCERTAINTY ON EUR ORG
# ALPS Equal Sector Weight ETF ORG
# EQL ORG
# the First Trust Capital Strength ORG
# FTCS ORG
# U.S. GPE
# Friday DATE
# the Federal Reserve ORG
# Monday DATE
# West LOC
# Russia GPE
# Ukraine GPE
# Immediate Release ORG
# Chicago GPE
# IL GPE
# February 7 DATE
# Blog PERSON
# the Zacks Equity Research ORG
# March 3 DATE
# Reuters ORG
# U.S. GPE
# Thursday DATE
# Federal Reserve Chair ORG
# Federal Reserve ORG
# 2021 DATE
# Bank of America ORG
# Reuters ORG
# Reuters ORG
# March 1 DATE
# Reuters ORG
# U.S. GPE
# Tuesday DATE
# Russia GPE
# Ukraine GPE
# Feb 15 DATE
# Reuters ORG
# U.S. GPE
# Tuesday DATE
# Russia GPE
# Ukrainian NORP
# two CARDINAL
# NEW YORK GPE
# Feb 28 DATE
# Warren Buffett PERSON
# Berkshire Hathaways PERSON
# annual DATE
# US GPE
# 1000 CARDINAL
# ETF ORG
# SCHK ORG
# more than 10% PERCENT
# Reuters ORG
# INDIVIDUAL INVESTORS WE ORG
# Reuters ORG
# REGIONAL ORG
# WEAT ORG
# Reuters ORG
# up to 2% PERCENT
# Dow ORG
# more than 1% PERCENT
# Tuesday DATE
# Russia GPE
# Ukraine GPE
# U.S. GPE
# more than 1% PERCENT
# Tuesday DATE
# Ukraine GPE
# Reuters ORG
# FILE ORG
# the New York Stock Exchange ORG
# NYSE ORG
# New York City GPE
# U.S. GPE
# January 26, 2022 DATE
# REUTERS ORG
# Brendan McDermid PERSON
# Reuters ORG
# U.S. GPE
# Wednesday DATE
# quarterly DATE
# 500 CARDINAL
# 500 CARDINAL
# first ORDINAL
# two years DATE
# 500 CARDINAL
# SPX ORG
# -1.84% PERCENT
# 1.8% PERCENT
# NEW YORK GPE
# Feb 18 DATE
# Reuters ORG
# U.S. GPE
# Federal Reserve ORG
# Russia GPE
# Ukraine GPE
# U.S. GPE
# NEW YORK GPE
# Feb 21 DATE
# Reuters ORG
# U.S. GPE
# Monday DATE
# Russian NORP
# Vladimir Putin PERSON
# two CARDINAL
# Ukraine GPE
# Ukraine GPE
# Russia GPE
# Reuters ORG
# Feb 8 DATE
# Reuters ORG
# Asian NORP
# U.S. GPE
# Reuters ORG
# U.S. GPE
# Reuters ORG
# BROADLY ORG
# NEW YORK GPE
# Reuters ORG
# U.S. GPE
# Russias PERSON
# Ukraine GPE
# the Federal Reserve ORG
# 500 CARDINAL
# Global Payments (GPN ORG
# quarterly DATE
# its fiscal year 2021 DATE
# fourth ORDINAL
# Reuters ORG
# REMAIN OV ORG
# Feb 23 DATE
# Reuters ORG
# U.S. GPE
# Wednesday DATE
# Russia GPE
# Ukraine GPE
